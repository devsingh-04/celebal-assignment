# %%
import sys
import os

# Get the absolute path to the scripts folder
SCRIPT_DIR = os.path.abspath(os.path.join(os.getcwd(), "..", "scripts"))

# Add it to Python's system path
if SCRIPT_DIR not in sys.path:
    sys.path.append(SCRIPT_DIR)

# %%
from load_data import load_and_save_dataset
from preprocessing import preprocess_dataframe, get_tfidf_matrix
from kmeans_model import run_kmeans, get_top_keywords_per_cluster
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 from load_data import load_and_save_dataset
# ----> 2 from preprocessing import preprocess_dataframe, get_tfidf_matrix
#       3 from kmeans_model import run_kmeans, get_top_keywords_per_cluster
#
# File ~/Desktop/Celebal_Assignment/celebal-assignment/data-modelling/scripts/preprocessing.py:4
#       2 import re
#       3 import string
# ----> 4 import nltk
#       5 from nltk.corpus import stopwords
#       6 from nltk.stem import WordNetLemmatizer
#
# ModuleNotFoundError: No module named 'nltk'

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import nltk
#       2 nltk.download('stopwords')
#       3 nltk.download('wordnet')
#
# ModuleNotFoundError: No module named 'nltk'

# %%
from preprocessing import preprocess_dataframe, get_tfidf_matrix
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from preprocessing import preprocess_dataframe, get_tfidf_matrix
#
# File ~/Desktop/Celebal_Assignment/celebal-assignment/data-modelling/scripts/preprocessing.py:4
#       2 import re
#       3 import string
# ----> 4 import nltk
#       5 from nltk.corpus import stopwords
#       6 from nltk.stem import WordNetLemmatizer
#
# ModuleNotFoundError: No module named 'nltk'

# %%
# !pip install nltk
# Out:
# ...
#   Using cached nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached regex-2024.11.6-cp313-cp313-macosx_11_0_arm64.whl.metadata (40 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Using cached regex-2024.11.6-cp313-cp313-macosx_11_0_arm64.whl (284 kB)
# Using cached click-8.2.1-py3-none-any.whl (102 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [nltk]3/4 [nltk]
# ...

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/devsingh/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/devsingh/nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/devsingh/nltk_data...
# True

# %%
from preprocessing import preprocess_dataframe, get_tfidf_matrix
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/devsingh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/devsingh/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/devsingh/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
import pandas as pd

df = pd.read_csv("../data/raw/20_newsgroups.csv")

# %%
df_clean = preprocess_dataframe(df)
# Out:
# 🔧 Preprocessing text data...

# %%
X_tfidf, tfidf_vectorizer = get_tfidf_matrix(df_clean["clean_text"])
# Out:
# 📊 Creating TF-IDF matrix...

# %%
import os
os.makedirs("../output", exist_ok=True)

# %%
df_clean.to_csv("../output/cleaned_20newsgroups.csv", index=False)

# %%
from scripts.lda_model import get_lda_count_matrix, run_lda, get_lda_topics

# Step 1: Count Vectorizer
X_count, count_vectorizer = get_lda_count_matrix(df_clean['clean_text'])

# Step 2: Run LDA
lda_model = run_lda(X_count, n_topics=10)

# Step 3: Get Topics
lda_topics = get_lda_topics(lda_model, count_vectorizer)

# Step 4: Print topics
for i, topic in enumerate(lda_topics):
    print(f"Topic {i}: {', '.join(topic)}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from scripts.lda_model import get_lda_count_matrix, run_lda, get_lda_topics
#       3 # Step 1: Count Vectorizer
#       4 X_count, count_vectorizer = get_lda_count_matrix(df_clean['clean_text'])
#
# ModuleNotFoundError: No module named 'scripts'

# %%
from lda_model import get_lda_count_matrix, run_lda, get_lda_topics

# %%
# Step 1: Count Vectorizer
X_count, count_vectorizer = get_lda_count_matrix(df_clean['clean_text'])

# Step 2: Run LDA
lda_model = run_lda(X_count, n_topics=10)

# Step 3: Get Topics
lda_topics = get_lda_topics(lda_model, count_vectorizer)

# Step 4: Print topics
for i, topic in enumerate(lda_topics):
    print(f"Topic {i}: {', '.join(topic)}")
# Out:
# 📚 Creating CountVectorizer matrix for LDA...
# 🧠 Running LDA with 10 topics...
# 📝 Extracting top words for each topic...
# Topic 0: space, year, new, program, study, research, university, information, april, disease
# Topic 1: maxaxaxaxaxaxaxaxaxaxaxaxaxaxax, drive, key, chip, scsi, encryption, disk, bit, clipper, use
# Topic 2: like, dont, time, know, think, im, good, thing, car, people
# Topic 3: card, thanks, know, like, im, email, price, mac, work, new
# Topic 4: game, team, year, player, play, think, president, mr, win, season
# Topic 5: image, available, list, data, information, software, book, send, computer, mail
# Topic 6: god, jesus, christian, church, bible, christ, word, say, man, sin
# Topic 7: armenian, people, said, government, state, child, war, jew, turkish, muslim
# Topic 8: file, window, program, use, problem, version, using, application, server, display
# Topic 9: people, dont, think, right, say, question, know, believe, make, point

# %%
# !pip install wordcloud

# %%
from visualization import create_wordclouds
create_wordclouds(lda_topics)
# Out:
# ☁️ Creating WordClouds...
# ✅ WordClouds saved.

# %%
from visualization import plot_tsne_clusters
plot_tsne_clusters(X_tfidf, labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 from visualization import plot_tsne_clusters
# ----> 2 plot_tsne_clusters(X_tfidf, labels)
#
# NameError: name 'labels' is not defined

# %%
from kmeans_model import run_kmeans

labels, model = run_kmeans(X_tfidf, n_clusters=10)
# Out:
# 🚀 Running KMeans with 10 clusters...

# %%
from visualization import plot_tsne_clusters
plot_tsne_clusters(X_tfidf, labels)
# Out:
# 📉 Creating t-SNE cluster plot...
# ✅ t-SNE plot saved to ../output/visualizations/kmeans_tsne.png
